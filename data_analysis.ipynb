# %% [markdown]
# # Importação dos Dados

# %%
import pandas as pd

# %% [markdown]
# ### Importação do Dataset para um Pandas DataFrame

# %%
df_raw = pd.read_csv('./files/combined_classified.csv')

# %% [markdown]
# ### Visualização dos Dados

# %%
df_raw.head()
# Out:
#                                                title  \
# 0  Cooperative Relative Localization in MAV Swarm...
# 1  Detection-Correction Structure via General Lan...
# 2  Average and Expected Distortion of Voronoi Pat...
# 3  Asynchronous BFT Asset Transfer: Quasi-Anonymo...
# 4  ReStorEdge: An edge computing system with reus...
#
#                                link published      retrieved_at  \
# 0  https://arxiv.org/abs/2405.18234       NaN  06/03/2024 00:00
# 1  https://arxiv.org/abs/2405.17804       NaN  06/03/2024 00:00
# 2  https://arxiv.org/abs/2012.03350       NaN  06/03/2024 00:00
# 3  https://arxiv.org/abs/2405.18072       NaN  06/03/2024 00:00
# 4  https://arxiv.org/abs/2405.17263       NaN  06/03/2024 00:00
#
#                                               author  \
# 0  Changrui Liu, Sven U. Pfeiffer, Guido C. H. E....
# 1                               Wei Li, Houfeng Wang
# 2              Herbert Edelsbrunner, Anton Nikitenko
# 3  Timoth\'e Albouy (IRISA), Emmanuelle Anceaume ...
# 4  Adrian-Cristian Nicolaescu (University College...
#
#                                             abstract  \
# 0  Relative localization (RL) is essential for th...
# 1  Grammatical error correction (GEC) is a task d...
# 2  The approximation of a circle with the edges o...
# 3  This article introduces a new asynchronous Byz...
# 4  This paper investigates an edge computing syst...
#
#                      category  isRelevant relevanceSource     classified_at
# 0                       cs.RO         0.0          Manual  06/04/2024 11:19
# 1                       cs.CL         0.0          Manual  06/04/2024 11:19
# 2            math.MG, math.PR         0.0          Manual  06/04/2024 11:19
# 3                       cs.DC         0.0          Manual  06/04/2024 11:19
# 4  cs.ET, cs.DB, cs.DC, cs.NI         0.0          Manual  06/04/2024 11:19

# %% [markdown]
# ### Cópia do DataFrame para Manipulação

# %%
df = df_raw.copy()

# %% [markdown]
# # Visualização dos Dados

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# ### Distribuição de Relevância

# %%
pcts = df['isRelevant'].value_counts(normalize=True) * 100
plt.figure(figsize=(4,4))
plt.pie(pcts, labels=pcts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribuição de Relevância (%)')
plt.show()

# %% [markdown]
# ### Distribuição de Artigos Classificados por Modelo

# %%
sns.countplot(data=df, x='relevanceSource', hue='isRelevant', palette=['orange', 'blue'])
plt.title('Distribuição de Artigos Classificados por Modelo')
plt.xlabel('Modelo de Classificação')
plt.ylabel('Número de Artigos')
plt.xticks(rotation=45)
plt.legend(title='Relevância', labels=['Irrelevante', 'Relevante'])
plt.show()

# %% [markdown]
# ### Taxa de Relevância por Modelo

# %%
relevant_by_model = df.groupby('relevanceSource')['isRelevant'].mean()

relevant_by_model.plot(kind='bar', color='green', figsize=(8, 5))
plt.title('Taxa de Relevância por Modelo')
plt.xlabel('Modelo de Classificação')
plt.ylabel('Proporção de Artigos Relevantes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Word Cloud dos Abstracts Relevantes

# %%
relevant_abstracts = ' '.join(df[df['isRelevant'] == 1]['abstract'].dropna())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(relevant_abstracts)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud dos Abstracts Relevantes')
plt.show()

# %% [markdown]
# ### Distribuição do Tamanho dos Abstracts

# %%
df['abstract_length'] = df['abstract'].str.split().str.len()

plt.hist(df['abstract_length'],color='purple', alpha=0.7)
plt.title('Distribuição do Tamanho dos Abstracts')
plt.xlabel('Número de Palavras')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Artigos com os maiores abstracts

# %%
df.sort_values(by='abstract_length', ascending=False, inplace=False).head()
# Out:
#                                                    title  \
# 34028  The Economic Crisis and the Fiscal Crisis: 200...
# 20550  An Institutional Innovation to Reduce the Agen...
# 13498  Ten Years After: Reflections on the Global Fin...
# 15176  Financial Risk Management and Explainable Trus...
# 13651  A machine learning approach to support decisio...
#
#                                                     link         published  \
# 34028  https://papers.ssrn.com/sol3/papers.cfm?abstra...  02/11/2011 00:00
# 20550  https://papers.ssrn.com/sol3/papers.cfm?abstra...    3/1/2023 15:48
# 13498  https://papers.ssrn.com/sol3/papers.cfm?abstra...  11/12/2019 18:17
# 15176  https://papers.ssrn.com/sol3/papers.cfm?abstra...     7/8/2021 6:35
# 13651  https://papers.ssrn.com/sol3/papers.cfm?abstra...  12/27/2022 20:05
#
#            retrieved_at                                             author  \
# 34028  06/20/2024 14:52                  William G. Gale, Alan J. Auerbach
# 20550  06/07/2024 11:04        Yakov Amihud, Kenneth Garbade, Marcel Kahan
# 13498  06/07/2024 16:37  Laurence B. Siegel, Luis Garc&iacute;a-Feij&oa...
# 15176  06/07/2024 16:33  Sebastian Fritz-Morgenthal, Bernhard Hein, Joc...
# 13651  06/07/2024 16:37  Piero Mazzarisi, Adele Ravagnani, Paola Deriu,...
#
#                                                 abstract category  isRelevant  \
# 34028  At the beginning of the decade, the U.S. fisca...      NaN         0.0
# 20550  Debt financing gives rise to conflicts of inte...      NaN         0.0
# 13498  The “Ten Years After” Brief contains summaries...      NaN         0.0
# 15176  This perspective paper is based on several ses...      NaN         0.0
# 13651  <b>English Abstract</b>: The identification of...      NaN         0.0
#
#               relevanceSource     classified_at  abstract_length
# 34028  randomForestClassifier  08/16/2024 11:53           1985.0
# 20550                  Manual  06/11/2024 16:24            840.0
# 13498  randomForestClassifier  08/16/2024 11:53            810.0
# 15176  randomForestClassifier  08/16/2024 11:53            796.0
# 13651  randomForestClassifier  08/16/2024 11:53            763.0

# %%
# remove o artigo com o abstract muito maior q os outros
df = df.drop(34028)

df['abstract_length'] = df['abstract'].str.split().str.len()

plt.hist(df['abstract_length'],color='purple', alpha=0.7)
plt.title('Distribuição do Tamanho dos Abstracts')
plt.xlabel('Número de Palavras')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Relação entre Tamanho dos Abstracts e Relevância

# %%
sns.boxplot(x='isRelevant', y='abstract_length', data=df, palette=['orange', 'blue'], hue='isRelevant', legend=False)
plt.title('Relação entre Tamanho dos Abstracts e Relevância')
plt.xlabel('Relevância (1 = Relevante, 0 = Irrelevante)')
plt.ylabel('Tamanho do Abstract (Número de Palavras)')
plt.show()
